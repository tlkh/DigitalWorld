# %% [markdown]
# ## Data Exploration

# %% [markdown]
# **1. Find our experiment records**

# %%
# !rm data/.DS_Store
from os import listdir
from os.path import isfile, join
data_raw = [f for f in listdir("data") if isfile(join("data", f))]
print(len(data_raw), "files:", str(data_raw))
# Out:
# rm: data/.DS_Store: No such file or directory
# 15 files: ['18.3.txt', '16.8.txt', '60.5.txt', '30.9.txt', '37.9.txt', '24.3.txt', '39.4.txt', '15.9.txt', '47.5.txt', '52.8.txt', '17.7.txt', '15.1.txt', '50.0.txt', '56.5.txt', '21.8.txt']

# %% [markdown]
# **2. Save into a dictionary**

# %%
import csv
import numpy as np
data = {}
for experiment in data_raw:
    t, temp = [], []
    with open("data/"+experiment) as csvfile:
        print(experiment)
        readCSV = csv.reader(csvfile, delimiter=',')
        for row in readCSV:
            t.append(int(row[0])/1e3)
            temp.append(float(row[1]))
        data[experiment[:-4]] = (np.array(t), np.array(temp))
# Out:
# 18.3.txt
# 16.8.txt
# 60.5.txt
# 30.9.txt
# 37.9.txt
# 24.3.txt
# 39.4.txt
# 15.9.txt
# 47.5.txt
# 52.8.txt
# 17.7.txt
# 15.1.txt
# 50.0.txt
# 56.5.txt
# 21.8.txt

# %% [markdown]
# **3. Plot `xkcd` style!!!**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.figure(1, figsize=(16, 14))
plt.title("Experimental Data")
plt.xlabel("Time (s)")
plt.xticks(np.arange(0, 130, step=20))
plt.xlim(0,150)
plt.yticks(np.arange(0, 61, step=5))
plt.ylabel("Temperature (°C)")
ordered_experiments = list(data.keys())
ordered_experiments.sort()
for experiment in ordered_experiments[::-1]:
    t, temp = data[experiment]
    plt.plot(t, temp, '--', label=r"$T_i$="+experiment)
    if float(experiment) < 28:
        label = round(float(experiment) - temp.min(), 2)
    else:
        label = round(float(experiment) - temp.max(), 2)
    plt.text(t[-1]+0.6,temp[-1]-0.3, r"$T$="+experiment+r", $\Delta$="+str(label))
    #plt.axhline(y=float(experiment), linestyle='--')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import *
from keras.layers import *
def normalise_values(train_x, train_y):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_x)
    scaled_x = scaler.transform(train_x)
    scaled_x = scaled_x.reshape(scaled_x.shape[0], 1, scaled_x.shape[1])

    scaler = scaler.fit(train_y)
    scaled_y = scaler.transform(train_y)
    scaled_y = scaled_y.reshape(scaled_y.shape[0],scaled_y.shape[1])
    
    return scaled_x[:160], scaled_y[:160]

train_x = data["60.5"][1][:-1].reshape(-1, 1)
train_y = data["60.5"][1][1:].reshape(-1, 1)
scaled_x, scaled_y = normalise_values(train_x, train_y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
"""model = Sequential()
model.add(LSTM(20, batch_input_shape=(1, scaled_x.shape[1], scaled_x.shape[2]), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])"""
# Out:
# "model = Sequential()\nmodel.add(LSTM(20, batch_input_shape=(1, scaled_x.shape[1], scaled_x.shape[2]), stateful=True))\nmodel.add(Dense(1))\nmodel.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])"

# %%
sequence_input = Input(batch_shape=(1,scaled_x.shape[1], scaled_x.shape[2]), dtype='float32')
lstm_1 = LSTM(20,return_sequences=False, stateful=True)(sequence_input)
lstm_2 = LSTM(20,return_sequences=False, stateful=True)(sequence_input)
merge = Concatenate(axis=1)([lstm_1, lstm_2])
dense_1 = Dense(128)(merge)
output = Dense(1)(dense_1)
model = Model(sequence_input, output)
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (1, 1, 1)            0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (1, 20)              1760        input_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (1, 20)              1760        input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (1, 40)              0           lstm_1[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (1, 128)             5248        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (1, 1)               129         dense_1[0][0]
# ==================================================================================================
# Total params: 8,897
# Trainable params: 8,897
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# input_1
# lstm_1
# lstm_2
# concatenate_1
# dense_1
# dense_2

# %%
for layer in model.layers:
    layer.trainable = True
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])

for i in range(2):
    for experiment in data.keys():
        if float(experiment) > 50:
            print(experiment, end=": ")
            train_x = data[experiment][1][:-1].reshape(-1, 1)
            train_y = data[experiment][1][1:].reshape(-1, 1)
            scaled_x, scaled_y = normalise_values(train_x, train_y)
            model.fit(scaled_x, scaled_y, epochs=1, batch_size=1, verbose=1, shuffle=False)
            model.reset_states()
            
for layer in model.layers:
    if str(layer.name) == "lstm_1":
        print("freezing", layer.name)
        layer.trainable = False
    else:
        layer.trainable = True
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
        
for i in range(2):
    for experiment in data.keys():
        if float(experiment) < 20:
            print(experiment, end=": ")
            train_x = data[experiment][1][:-1].reshape(-1, 1)
            train_y = data[experiment][1][1:].reshape(-1, 1)
            scaled_x, scaled_y = normalise_values(train_x, train_y)
            model.fit(scaled_x, scaled_y, epochs=1, batch_size=1, verbose=1, shuffle=False)
            model.reset_states()
            
for layer in model.layers:
    if str(layer.name) == "lstm_1" or str(layer.name) == "lstm_2":
        print("freezing", layer.name)
        layer.trainable = False
    else:
        layer.trainable = True
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
        
for i in range(1):
    for experiment in data.keys():
            print(experiment, end=": ")
            train_x = data[experiment][1][:-1].reshape(-1, 1)
            train_y = data[experiment][1][1:].reshape(-1, 1)
            scaled_x, scaled_y = normalise_values(train_x, train_y)
            model.fit(scaled_x, scaled_y, epochs=1, batch_size=1, verbose=1, shuffle=False)
            model.reset_states()
            
for layer in model.layers:
    if str(layer.name) == "lstm_2":
        print("freezing", layer.name)
        layer.trainable = False
    else:
        layer.trainable = True
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])        

for i in range(2):
    for experiment in data.keys():
        if float(experiment) > 50:
            print(experiment, end=": ")
            train_x = data[experiment][1][:-1].reshape(-1, 1)
            train_y = data[experiment][1][1:].reshape(-1, 1)
            scaled_x, scaled_y = normalise_values(train_x, train_y)
            model.fit(scaled_x, scaled_y, epochs=1, batch_size=1, verbose=1, shuffle=False)
            model.reset_states()
# Out:
# 60.5: Epoch 1/1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0026 - mean_absolute_error: 0.0259 - acc: 0.2125
# 52.8: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0274 - acc: 0.2375
# 56.5: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0286 - acc: 0.1187
# 60.5: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0043 - mean_absolute_error: 0.0331 - acc: 0.2125
# 52.8: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0239 - acc: 0.2375
# 56.5: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0324 - acc: 0.1187
# freezing lstm_1
# 18.3: Epoch 1/1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0041 - mean_absolute_error: 0.0361 - acc: 0.1438
# 16.8: Epoch 1/1
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0035 - mean_absolute_error: 0.0237 - acc: 0.0813
# 15.9: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0174 - acc: 0.1062
# 17.7: Epoch 1/1
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0221 - acc: 0.1187
# 15.1: Epoch 1/1
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0244 - acc: 0.1125
# 18.3: Epoch 1/1
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0221 - acc: 0.1438
# 16.8: Epoch 1/1
# 160/160 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0294 - acc: 0.096 - 1s 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0272 - acc: 0.0875
# 15.9: Epoch 1/1
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0188 - acc: 0.1062
# 17.7: Epoch 1/1
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0249 - acc: 0.1187
# 15.1: Epoch 1/1
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0196 - acc: 0.1125
# freezing lstm_1
# freezing lstm_2
# 18.3: Epoch 1/1
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0207 - acc: 0.1438
# 16.8: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0186 - acc: 0.0875
# 60.5: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0294 - acc: 0.2125
# 30.9: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0036 - mean_absolute_error: 0.0273 - acc: 0.3188
# 37.9: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0316 - acc: 0.3000
# 24.3: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0419 - acc: 0.1500
# 39.4: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0036 - mean_absolute_error: 0.0316 - acc: 0.2125
# 15.9: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0036 - mean_absolute_error: 0.0318 - acc: 0.1062
# 47.5: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0307 - acc: 0.1250
# 52.8: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0244 - acc: 0.2313
# 17.7: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0272 - acc: 0.1187
# 15.1: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0197 - acc: 0.1062
# 50.0: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0225 - acc: 0.1812
# 56.5: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0216 - acc: 0.1187
# 21.8: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0286 - acc: 0.0875
# freezing lstm_2
# 60.5: Epoch 1/1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0044 - mean_absolute_error: 0.0443 - acc: 0.2125
# 52.8: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0178 - acc: 0.2313
# 56.5: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0238 - acc: 0.1187
# 60.5: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0361 - acc: 0.2125
# 52.8: Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0268 - acc: 0.2313
# 56.5: Epoch 1/1
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0220 - acc: 0.1187

# %%
plt.figure(1, figsize=(16, 14))
plt.title("Experimental Data")
plt.xlabel("Time (s)")
plt.xticks(np.arange(0, 130, step=20))
plt.xlim(0,150)
plt.yticks(np.arange(0, 61, step=5))
plt.ylabel("Temperature (°C)")
ordered_experiments = list(data.keys())
ordered_experiments.sort()
pred_constant = 160
for experiment in ordered_experiments[::-1]:
    t, temp = data[experiment]
    temp_pred = []
    time_label = str(t[pred_constant])+"s - "
    for T in temp[:pred_constant]:
        T = (T - temp.min())/(temp.max()-temp.min())
        pred = model.predict(np.array([T]).reshape(1,1,1))[0][0]
        temp_pred.append(pred*(temp.max()-temp.min())+temp.min())
    while (abs(temp_pred[-1] - temp_pred[-2]) > 0.0001) and len(temp_pred) < len(temp):
        T = temp_pred[-1]
        T = (T - temp.min())/(temp.max()-temp.min())
        pred = model.predict(np.array([T]).reshape(1,1,1))[0][0]
        temp_pred.append(pred*(temp.max()-temp.min())+temp.min())
    model.reset_states()
    plt.plot(t, temp, '--', label=r"$T_i$="+experiment)
    plt.plot(t[:len(temp_pred)], temp_pred, '-')
    if float(experiment) < 28:
        label = round(float(experiment) - temp.min(), 2)
    else:
        label = round(float(experiment) - temp.max(), 2)
    plt.text(t[-1]+0.6,temp[-1]-0.3, r"$T$="+experiment+r", $\Delta$="+str(label))
    plt.text(t[:len(temp_pred)][-1]-0.6,temp_pred[-1]-0.3, time_label+str(round(temp_pred[-1],1)))
plt.legend()
plt.show()
